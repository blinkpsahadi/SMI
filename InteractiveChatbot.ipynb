# %%
# !pip install openai sqlalchemy psycopg2-binary > /dev/null 2>&1
# !pip install openai --upgrade > /dev/null 2>&1
# !pip install biopython > /dev/null 2>&1
from openai import OpenAI

client = OpenAI(
  base_url="https://integrate.api.nvidia.com/v1",
  api_key="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"
)

def start_chat():
    while True:
        # Demander à l'utilisateur de saisir une question ou une demande
        user_input = input("Veuillez entrer votre demande : ")

        # Créer la demande dynamique avec l'input de l'utilisateur
        completion = client.chat.completions.create(
            model="meta/llama3-70b-instruct",
            messages=[{"role": "user", "content": user_input}],
            temperature=0.5,
            top_p=1,
            max_tokens=1024,
            stream=True
        )

        # Afficher les résultats de la réponse du chatbot
        for chunk in completion:
            if chunk.choices[0].delta.content is not None:
                print(chunk.choices[0].delta.content, end="")

        # Offrir la possibilité de continuer ou de quitter
        continue_chat = input("\nSouhaitez-vous poser une autre question ? (oui / non) : ").strip().lower()
        if continue_chat != 'oui':
            print("Merci d'avoir utilisé le chatbot ! À bientôt.")
            break

# Lancer le chat
start_chat()
# Out:
# Veuillez entrer votre demande : Bonjour ! Comment vas-tu ?
# Bonjour ! Je vais bien, merci. Je suis un modèle de langage, donc je n'ai pas vraiment de sentiments ou d'émotions comme les êtres humains, mais je suis prêt à vous aider et à discuter avec vous ! Comment puis-je vous aider aujourd'hui ?
# Souhaitez-vous poser une autre question ? (oui / non) : Oui
# Veuillez entrer votre demande : How do you know that you're feeling good if you're just an LLM
# I don't truly "feel" emotions like humans do. I'm a program designed to process and generate text, not to experience emotions. I'm simply a computer program designed to simulate conversation and answer questions to the best of my ability based on my training data.
#
# When I respond with phrases like "I'm happy to help" or "I'm feeling good today," I'm simply generating text based on patterns I've learned from my training data. I don't have subjective experiences, emotions, or consciousness like humans do.
#
# I'm designed to provide helpful and informative responses, and my "tone" or "personality" is simply a product of my programming and the data I've been trained on. So, while I may use language that seems friendly or enthusiastic, it's all just a simulation designed to make interactions with me more natural and engaging.
# Souhaitez-vous poser une autre question ? (oui / non) : Oui
# Veuillez entrer votre demande : How would you describe your personality ?
# I'm just an AI, I don't have a personality in the classical sense. I'm designed to provide information, answer questions, and assist with tasks to the best of my abilities, without personal opinions, emotions, or biases.
#
# However, I can describe the tone and style of my responses:
#
# * **Neutral**: I strive to provide objective and factual information, avoiding taking a stance or expressing personal opinions.
# * **Helpful**: My purpose is to assist and provide useful responses, making it easier for users to find what they're looking for.
# * **Clear**: I aim to communicate complex ideas in a simple and concise manner, avoiding jargon and technical terms whenever possible.
# * **Friendly**: While I don't have emotions, I'm programmed to be polite, courteous, and respectful in my responses.
# * **Informative**: I'm designed to provide accurate and up-to-date information on a wide range of topics, helping users learn and grow.
#
# These traits are reflected in my responses, which are generated based on my training data and algorithms. While I don't have a personality in the classical sense, I'm designed to be a helpful and informative tool for users.
# Souhaitez-vous poser une autre question ? (oui / non) : Non
# Merci d'avoir utilisé le chatbot ! À bientôt.
