# %%
# !pip install openai sqlalchemy psycopg2-binary > /dev/null 2>&1
# !pip install openai --upgrade > /dev/null 2>&1
# !pip install biopython > /dev/null 2>&1

# Importation des bibliothèques nécessaires
from Bio import Entrez, Medline
from transformers import pipeline
import concurrent.futures
import openai

# Configuration de l'email pour Entrez
Entrez.email = "worthylastchance@gmail.com"

openai.api_key = "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"
pubmed_query = "soft mist inhaler"  # Example query
retmax = 5  # Number of records to retrieve (max 100,000 per query)

# Retrieve PubMed IDs
handle = Entrez.esearch(db='pubmed',
                        sort='relevance',
                        retmax=retmax,
                        retmode='text',
                        term=pubmed_query)
record = Entrez.read(handle)
handle.close()
idlist = record["IdList"]

# Fetch & Print Article Details and Summarize
for id in idlist:
    handle = Entrez.efetch(db='pubmed', rettype='medline', retmode='text', id=id)
    record = Medline.read(handle)
    handle.close()

    # Extract relevant info
    title = record.get("TI", "")
    abstract = record.get("AB", "")
    print(f"**Title:** {title}\n**Abstract:**\n{abstract}")

    def summarize_abstract(abstract):
        try:
            prompt = f"Résumer le résumé suivant en 50 mots:\n{abstract}"
            openai_params = {
                "engine": "gpt-4",  # Utilisation de GPT-4
                "prompt": prompt,
                "temperature": 0.5,  # Une valeur plus basse pour plus de cohérence
                "max_tokens": 100,  # Ajustez selon vos besoins de longueur de réponse
                "top_p": 1,
                "frequency_penalty": 0.2  # Peut aider à réduire les répétitions
            }
            response = openai.Completion.create(**openai_params)

            # Récupération et affichage du résumé généré
            if response.choices:
                generated_summary = response.choices[0].text.strip()
                print(f"**Résumé Généré (GPT-4):**\n{generated_summary}\n---\n")
            else:
                print("**Erreur:** Aucun résumé généré reçu de l'API OpenAI.\n---\n")

        except openai.OpenAIError as e:
            print(f"**Erreur OpenAI:** {e}\n---\n")
        except Exception as e:
            print(f"**Erreur Inattendue:** {e}\n---\n")

    # Appelez la fonction pour chaque abstract
# Out:
# **Title:** The Respimat((R)) Soft Mist Inhaler: Implications of Drug Delivery Characteristics for Patients.
# **Abstract:**
# ...

# %%
# !pip install openai sqlalchemy psycopg2-binary > /dev/null 2>&1
# !pip install openai --upgrade > /dev/null 2>&1
# !pip install biopython > /dev/null 2>&1
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)

completion = client.chat.completions.create(
  model="meta/llama3-70b-instruct",
  messages=[{"role":"user","content":" look for 5 of the most recent online articles about soft mist inhalers and give me their summary, their publication date, their DOI, as well as their sources and a direct link to access these articles"}],
  temperature=0.5,
  top_p=1,
  max_tokens=1024,
  stream=True
)

for chunk in completion:
  if chunk.choices[0].delta.content is not None:
    print(chunk.choices[0].delta.content, end="")
# Out:
# After conducting a search, I found 5 recent online articles about soft mist inhalers. Here are the summaries, publication dates, DOIs, sources, and direct links to access these articles:
#
# **Article 1:**
# **Title:** "Soft Mist Inhalers: A Review of the Literature"
# **Summary:** This review article discusses the principles, advantages, and limitations of soft mist inhalers (SMIs) in the treatment of respiratory diseases. The authors highlight the benefits of SMIs, including improved lung deposition, reduced oropharyngeal deposition, and enhanced patient compliance.
# **Publication Date:** October 2020
# **DOI:** 10.1016/j.rmed.2020.09.012
# **Source:** Respiratory Medicine
# **Direct Link:** https://www.sciencedirect.com/science/article/pii/S0954611120302346
#
# **Article 2:**
# **Title:** "Comparative Study of Lung Deposition of Fluticasone Propionate Delivered via Soft Mist Inhaler and Pressurized Metered-Dose Inhaler"
# ...
